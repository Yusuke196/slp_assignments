# %% [markdown]
# ## Summary

# %% [markdown]
# This is a question about how to deal with OOV tokens or ngrams. Specifically, supposing I am building a 4-gram language model, I will need to compute something like P(token|context_of_three_tokens), but I'm not sure how to do this when the context is unseen in the training data (that is, $\sum_v C(w_i w_j w_k v)$ may well equal 0).
#
# When I read 3.4 of SLP, one of the suggested ways to determine goes like this.
#
# > Convert in the training set any word that is not in this set (any OOV word) to
# the unknown word token <UNK> in a text normalization step.
#
# > The second alternative, in situations where we don’t have a prior vocabulary in ad- vance, is to create such a vocabulary implicitly, replacing words in the training data by \<UNK> based on their frequency.
#
# I understand this approach works with a unigram language model. However, when you make the n of ngram larger, the number of rare ngrams increases too. So, it is difficult to do something like "When there is an unseen sequence in the test set, replace it with \<UNK SEQ> and assume P(\<UNK SEQ>) equals to the count of ngrams of the same length which appear only once in the training data".

# %% [markdown]
# ## Environment

# %%
# !python --version
# Out:
# Python 3.9.9

# %%
# !pip list | grep nltk
# Out:
# nltk                 3.6.7

# %% [markdown]
# ## Answer by Vu-san

# %% [markdown]
# This (too high UNK sequence ratio) happens because the dataset is too limited or small. In reality, we don't meet phenomen like that because the dataset is much larger. Usually, the ratio of UNK sequence is around 5%.

# %% [markdown]
# ## Codes

# %%
from traditional_lm import Lm

# %%
with open('data/wiki-en-train.word') as file:
    train = [['<s>'] + line.lower().split() + ['</s>'] for line in file]

# %%
trigram = Lm(n=3)
trigram.fit(train)

# %%
trigram.ngram_freq
# Out:
# {'<UNK> . </s>': 147,
#  '-rrb- . </s>': 101,
#  '<UNK> , <UNK>': 86,
#  '<UNK> <UNK> ,': 53,
#  ', <UNK> ,': 49,
#  ', <UNK> <UNK>': 49,
#  'for example ,': 47,
#  '<s> for example': 35,
#  '-lrb- <UNK> -rrb-': 34,
#  ', such as': 33,
#  '<s> however ,': 32,
#  'the <UNK> of': 32,
#  'natural language processing': 28,
#  'text . </s>': 26,
#  '<UNK> and <UNK>': 26,
#  ', and <UNK>': 23,
#  '<UNK> of the': 23,
#  'a number of': 22,
#  '<UNK> , and': 21,
#  '<s> it is': 19,
#  '-lrb- e.g. ,': 19,
#  'the <UNK> <UNK>': 18,
#  '<UNK> <UNK> <UNK>': 18,
#  'in the <UNK>': 18,
#  'of natural language': 17,
#  'data . </s>': 17,
#  '<UNK> -rrb- .': 17,
#  '<UNK> -rrb- ,': 16,
#  'words . </s>': 16,
#  ', the <UNK>': 15,
#  '<UNK> in the': 15,
#  'the use of': 15,
#  '<s> the <UNK>': 14,
#  '<UNK> -lrb- <UNK>': 14,
#  'a set of': 14,
#  'part of speech': 14,
#  '<s> this is': 14,
#  'of speech recognition': 14,
#  'to <UNK> the': 14,
#  'such as the': 14,
#  ', it is': 13,
#  '<UNK> to the': 13,
#  "`` <UNK> ''": 13,
#  "'' . </s>": 13,
#  '<UNK> of <UNK>': 13,
#  'as well as': 13,
#  '<UNK> to <UNK>': 13,
#  '<UNK> <UNK> .': 13,
#  '-lrb- citation needed': 13,
#  'citation needed -rrb-': 13,
#  'natural language understanding': 12,
#  'in the field': 12,
#  '<s> in the': 12,
#  'one of the': 12,
#  'such as <UNK>': 12,
#  'main article :': 12,
#  '-rrb- , and': 11,
#  'the process of': 11,
#  '-rrb- , <UNK>': 11,
#  'and <UNK> .': 11,
#  ', however ,': 11,
#  'of the <UNK>': 11,
#  'the brown corpus': 11,
#  'based on the': 11,
#  'system . </s>': 11,
#  "'' , ``": 11,
#  'language . </s>': 11,
#  'parts of speech': 11,
#  'summary . </s>': 11,
#  'keyphrases . </s>': 11,
#  '<s> thus ,': 11,
#  'can be <UNK>': 11,
#  'problem . </s>': 10,
#  ', for example': 10,
#  'and the <UNK>': 10,
#  'some of the': 10,
#  'systems . </s>': 10,
#  'of text ,': 10,
#  ', and the': 10,
#  'task . </s>': 10,
#  '<UNK> of a': 10,
#  'speech . </s>': 10,
#  'the field of': 9,
#  '<UNK> on the': 9,
#  'speech recognition systems': 9,
#  ', <UNK> and': 9,
#  ': given a': 9,
#  ', etc. -rrb-': 9,
#  'a <UNK> of': 9,
#  'of <UNK> .': 9,
#  'etc. . </s>': 9,
#  '<UNK> , the': 9,
#  'and <UNK> ,': 9,
#  '% . </s>': 9,
#  'for instance ,': 9,
#  '<UNK> , which': 9,
#  "'' and ``": 9,
#  'languages . </s>': 8,
#  'of a <UNK>': 8,
#  'of <UNK> <UNK>': 8,
#  'word . </s>': 8,
#  '. -rrb- </s>': 8,
#  'sentences . </s>': 8,
#  ', in the': 8,
#  'the complexity of': 8,
#  'such as ``': 8,
#  'is a <UNK>': 8,
#  'in order to': 8,
#  'in the text': 8,
#  '-lrb- such as': 8,
#  '-lrb- for example': 8,
#  '<UNK> the <UNK>': 8,
#  'to <UNK> <UNK>': 8,
#  'the target language': 8,
#  'of the text': 8,
#  'the <UNK> ,': 8,
#  '<UNK> in <UNK>': 8,
#  'the text .': 8,
#  'speech recognition is': 8,
#  '<s> natural language': 7,
#  'recognition . </s>': 7,
#  'a <UNK> <UNK>': 7,
#  ', <UNK> -rrb-': 7,
#  'processing . </s>': 7,
#  'machine translation ,': 7,
#  'is used to': 7,
#  ', which is': 7,
#  '<s> note that': 7,
#  'sentence . </s>': 7,
#  'answer . </s>': 7,
#  'is the <UNK>': 7,
#  '<s> speech recognition': 7,
#  'context . </s>': 7,
#  ', etc. .': 7,
#  'a series of': 7,
#  '<s> in <UNK>': 7,
#  'in <UNK> ,': 7,
#  'with respect to': 7,
#  'the <UNK> .': 7,
#  'in terms of': 7,
#  'accuracy . </s>': 7,
#  '<UNK> -rrb- and': 7,
#  ', <UNK> the': 7,
#  '<s> for instance': 7,
#  'a variety of': 7,
#  'the united states': 7,
#  'may be <UNK>': 7,
#  '<UNK> or <UNK>': 7,
#  '-lrb- i.e. ,': 7,
#  'to the <UNK>': 7,
#  ', e.g. ,': 7,
#  '<UNK> <UNK> and': 7,
#  'hidden markov models': 7,
#  'in speech recognition': 7,
#  'with the <UNK>': 6,
#  'is the process': 6,
#  'to <UNK> a': 6,
#  'developed in the': 6,
#  ', <UNK> -lrb-': 6,
#  'rules . </s>': 6,
#  'language processing .': 6,
#  '<UNK> <UNK> for': 6,
#  ', there is': 6,
#  'the task of': 6,
#  '<s> the first': 6,
#  'the penn treebank': 6,
#  'the most common': 6,
#  'it is often': 6,
#  'complexity of the': 6,
#  'process . </s>': 6,
#  'a list of': 6,
#  'of the most': 6,
#  'a chunk of': 6,
#  'chunk of text': 6,
#  'of the language': 6,
#  '<s> furthermore ,': 6,
#  ', and even': 6,
#  'it is a': 6,
#  'the meaning of': 6,
#  'also known as': 6,
#  'there are <UNK>': 6,
#  'speech recognition and': 6,
#  'language processing ,': 6,
#  'the <UNK> and': 6,
#  'the original text': 6,
#  ', and a': 6,
#  'and <UNK> <UNK>': 6,
#  ', as well': 6,
#  'the problem of': 6,
#  ', a <UNK>': 6,
#  'to be <UNK>': 6,
#  'of <UNK> ,': 6,
#  ', and so': 6,
#  'summarization . </s>': 6,
#  'in general ,': 6,
#  'example , if': 6,
#  'domain . </s>': 6,
#  '<s> the system': 6,
#  'summaries . </s>': 6,
#  ', on the': 6,
#  ', is the': 6,
#  'in natural language': 6,
#  'be used to': 6,
#  '<UNK> , but': 6,
#  'needed -rrb- .': 6,
#  'used in the': 6,
#  'of speech ,': 6,
#  'hidden markov model': 6,
#  'a sequence of': 6,
#  'analysis . </s>': 6,
#  'language processing -lrb-': 5,
#  'it . </s>': 5,
#  'nlp . </s>': 5,
#  'on the other': 5,
#  'the other hand': 5,
#  'other hand ,': 5,
#  'depends on the': 5,
#  'english . </s>': 5,
#  ', <UNK> to': 5,
#  'in the late': 5,
#  'of machine learning': 5,
#  "<UNK> 's <UNK>": 5,
#  '<UNK> <UNK> in': 5,
#  'for the <UNK>': 5,
#  'the nature of': 5,
#  'nature of the': 5,
#  'that can be': 5,
#  '-rrb- , the': 5,
#  'the development of': 5,
#  'been applied to': 5,
#  'similar to the': 5,
#  'systems based on': 5,
#  'the number of': 5,
#  'the fact that': 5,
#  '<UNK> , etc.': 5,
#  'natural language generation': 5,
#  'of natural languages': 5,
#  'optical character recognition': 5,
#  "'' can be": 5,
#  "? '' -rrb-": 5,
#  '<s> sentiment analysis': 5,
#  'a <UNK> ,': 5,
#  'knowledge of the': 5,
#  'speech recognition ,': 5,
#  'to be a': 5,
#  'in the context': 5,
#  'the context of': 5,
#  'and natural language': 5,
#  'by the <UNK>': 5,
#  ', and can': 5,
#  ', which are': 5,
#  'for a number': 5,
#  'of <UNK> and': 5,
#  '-lrb- see <UNK>': 5,
#  'in the target': 5,
#  '<s> -lrb- citation': 5,
#  'used . </s>': 5,
#  'can be used': 5,
#  'the time ,': 5,
#  'of the source': 5,
#  'as the <UNK>': 5,
#  'interlingual machine translation': 5,
#  '<UNK> that the': 5,
#  '<s> in this': 5,
#  'by <UNK> <UNK>': 5,
#  'and can be': 5,
#  'be able to': 5,
#  '<s> there are': 5,
#  'of an <UNK>': 5,
#  'in a <UNK>': 5,
#  'the relations between': 5,
#  'and so on': 5,
#  '<UNK> such as': 5,
#  'the summary .': 5,
#  '<s> in contrast': 5,
#  'in contrast ,': 5,
#  'to create a': 5,
#  ', where the': 5,
#  'document . </s>': 5,
#  'example , a': 5,
#  'in the case': 5,
#  'the case of': 5,
#  "'' , and": 5,
#  ', and ``': 5,
#  'documents . </s>': 5,
#  'phrases . </s>': 5,
#  'are based on': 5,
#  'with a <UNK>': 5,
#  '<UNK> by the': 5,
#  '-rrb- and the': 5,
#  'the <UNK> system': 5,
#  'such as those': 5,
#  '<UNK> ocr ,': 5,
#  'or a <UNK>': 5,
#  '% of the': 5,
#  'that is ,': 5,
#  'e.g. , <UNK>': 5,
#  'on a <UNK>': 5,
#  'the question ,': 5,
#  'sentiment analysis .': 5,
#  ". '' </s>": 5,
#  '<UNK> -lrb- e.g.': 5,
#  ', speech recognition': 5,
#  'for speech recognition': 5,
#  'speech recognition .': 5,
#  "'' by <UNK>": 5,
#  '-rrb- is a': 4,
#  'natural language input': 4,
#  'output . </s>': 4,
#  'referred to as': 4,
#  'machine learning .': 4,
#  'the late 1980s': 4,
#  'statistical machine translation': 4,
#  'a natural language': 4,
#  'or <UNK> ,': 4,
#  'example , <UNK>': 4,
#  '-lrb- <UNK> ,': 4,
#  '<UNK> <UNK> of': 4,
#  '<UNK> <UNK> the': 4,
#  'that <UNK> the': 4,
#  'has focused on': 4,
#  'input data .': 4,
#  'models . </s>': 4,
#  '<s> these systems': 4,
#  'take advantage of': 4,
#  ', which was': 4,
#  'algorithms . </s>': 4,
#  'the world wide': 4,
#  'world wide web': 4,
#  'the analysis of': 4,
#  'examples . </s>': 4,
#  'use of a': 4,
#  'each of which': 4,
#  'of speech for': 4,
#  'of the word': 4,
#  ', and to': 4,
#  'that has been': 4,
#  'tasks . </s>': 4,
#  'the identity of': 4,
#  'however , in': 4,
#  'be <UNK> .': 4,
#  'there is a': 4,
#  'different types of': 4,
#  'languages such as': 4,
#  'as <UNK> ,': 4,
#  'the type of': 4,
#  'example , the': 4,
#  'of which are': 4,
#  '<s> in fact': 4,
#  'in fact ,': 4,
#  "'' -rrb- </s>": 4,
#  'boundaries . </s>': 4,
#  'of the speech': 4,
#  'speech recognition -lrb-': 4,
#  ', so the': 4,
#  'of words in': 4,
#  'words in the': 4,
#  'information . </s>': 4,
#  '<UNK> , or': 4,
#  ', <UNK> m.': 4,
#  '<s> <UNK> <UNK>': 4,
#  ', a number': 4,
#  'of the system': 4,
#  'the system is': 4,
#  ', and then': 4,
#  'the quality of': 4,
#  'of a system': 4,
#  'are <UNK> to': 4,
#  'based on a': 4,
#  'of a text': 4,
#  ', is a': 4,
#  'a text ,': 4,
#  '<UNK> text .': 4,
#  'can also be': 4,
#  'has been <UNK>': 4,
#  'research . </s>': 4,
#  'on the <UNK>': 4,
#  'the source text': 4,
#  '<s> to <UNK>': 4,
#  '<s> this problem': 4,
#  ', which means': 4,
#  'transfer-based machine translation': 4,
#  'representation . </s>': 4,
#  'can be achieved': 4,
#  'by <UNK> and': 4,
#  'be viewed as': 4,
#  'to have a': 4,
#  'engine . </s>': 4,
#  'used to <UNK>': 4,
#  "<UNK> '' ,": 4,
#  'they can be': 4,
#  '<UNK> at the': 4,
#  'of discourse analysis': 4,
#  'and <UNK> the': 4,
#  'in the same': 4,
#  '<UNK> , james': 4,
#  'was able to': 4,
#  'relations between discourse': 4,
#  'between discourse and': 4,
#  'some kind of': 4,
#  'so on .': 4,
#  'on . </s>': 4,
#  ', <UNK> or': 4,
#  'paul <UNK> ,': 4,
#  '<UNK> , michael': 4,
#  ', michael <UNK>': 4,
#  'sentences in the': 4,
#  'in the original': 4,
#  'keyphrase extraction ,': 4,
#  'field . </s>': 4,
#  "'' or ``": 4,
#  'likely to be': 4,
#  'what are the': 4,
#  'of the first': 4,
#  ', the system': 4,
#  'algorithm . </s>': 4,
#  'training data .': 4,
#  ', and it': 4,
#  'based on some': 4,
#  '-lrb- as in': 4,
#  'as in the': 4,
#  "'' -rrb- ,": 4,
#  'in a text': 4,
#  "`` learning ''": 4,
#  ', or <UNK>': 4,
#  'in the summary': 4,
#  'in the document': 4,
#  'with regard to': 4,
#  'some form of': 4,
#  '<s> moreover ,': 4,
#  'has to be': 4,
#  'letters . </s>': 4,
#  'grass pollen levels': 4,
#  'be <UNK> in': 4,
#  '<UNK> , such': 4,
#  'in recent years': 4,
#  'process of <UNK>': 4,
#  'because of the': 4,
#  'to determine the': 4,
#  'years . </s>': 4,
#  ', for instance': 4,
#  'grammar . </s>': 4,
#  'applications . </s>': 4,
#  '<s> systems that': 4,
#  'state of the': 4,
#  'character recognition ,': 4,
#  'time . </s>': 4,
#  'the first <UNK>': 4,
#  '<UNK> system ,': 4,
#  'databases . </s>': 4,
#  ', which <UNK>': 4,
#  'ocr , <UNK>': 4,
#  'can not be': 4,
#  "`` dogs ''": 4,
#  'of the time': 4,
#  'a <UNK> .': 4,
#  '<UNK> , as': 4,
#  'the viterbi algorithm': 4,
#  '<s> the term': 4,
#  '-lrb- that is': 4,
#  '<s> <UNK> ,': 4,
#  'the answer to': 4,
#  'a sentence .': 4,
#  "speech recognition ''": 4,
#  '<UNK> speech recognition': 4,
#  'to recognize the': 4,
#  'recognize the speech': 4,
#  'dynamic time warping': 4,
#  ', neural networks': 4,
#  'segmentation is the': 4,
#  'processing -lrb- nlp': 3,
#  '-lrb- nlp -rrb-': 3,
#  'is a field': 3,
#  'a field of': 3,
#  'computer science ,': 3,
#  'it is the': 3,
#  'of a computer': 3,
#  'is a very': 3,
#  'sometimes referred to': 3,
#  'of computational linguistics': 3,
#  'the <UNK> for': 3,
#  'language processing systems': 3,
#  'machine learning ,': 3,
#  'learning . </s>': 3,
#  'statistics . </s>': 3,
#  'an example of': 3,
#  'a computer program': 3,
#  'the basis of': 3,
#  'human . </s>': 3,
#  'the georgetown experiment': 3,
#  '<s> the authors': 3,
#  ', machine translation': 3,
#  'would be a': 3,
#  'for machine translation': 3,
#  'late 1980s ,': 3,
#  ', when the': 3,
#  '<UNK> data .': 3,
#  'of hand-written rules': 3,
#  'however , there': 3,
#  'machine learning algorithms': 3,
#  '<UNK> and the': 3,
#  '<s> some of': 3,
#  'such as decision': 3,
#  'as decision trees': 3,
#  'decision trees ,': 3,
#  'research has focused': 3,
#  'are examples of': 3,
#  'many of the': 3,
#  'of machine translation': 3,
#  '<UNK> as a': 3,
#  'as a result': 3,
#  'the translation of': 3,
#  'a major <UNK>': 3,
#  'major <UNK> in': 3,
#  'the success of': 3,
#  'are able to': 3,
#  '<s> generally ,': 3,
#  'much more difficult': 3,
#  'more difficult than': 3,
#  '-rrb- , which': 3,
#  'set of documents': 3,
#  'that have been': 3,
#  '<s> consider the': 3,
#  'the correct part': 3,
#  'correct part of': 3,
#  'word in a': 3,
#  'of training data': 3,
#  'training data ,': 3,
#  ', each of': 3,
#  'each word .': 3,
#  'of such a': 3,
#  'text , and': 3,
#  'words , and': 3,
#  'the model that': 3,
#  'can be found': 3,
#  'the training data': 3,
#  'data , and': 3,
#  'of the words': 3,
#  'generated . </s>': 3,
#  'that they can': 3,
#  '<s> in addition': 3,
#  '<s> systems based': 3,
#  '<UNK> <UNK> -rrb-': 3,
#  '<s> in particular': 3,
#  'in particular ,': 3,
#  ', while others': 3,
#  'of text .': 3,
#  'text , determine': 3,
#  "'' -rrb- .": 3,
#  ', and is': 3,
#  'to . </s>': 3,
#  'example , in': 3,
#  ', in a': 3,
#  'the front door': 3,
#  "'' is a": 3,
#  '<s> discourse analysis': 3,
#  '-lrb- e.g. <UNK>': 3,
#  '<s> machine translation': 3,
#  'another . </s>': 3,
#  'is one of': 3,
#  'all of the': 3,
#  ', semantics ,': 3,
#  '<s> the difficulty': 3,
#  'the difficulty of': 3,
#  '-lrb- i.e. the': 3,
#  'the structure of': 3,
#  '-rrb- of the': 3,
#  'of a word': 3,
#  '-rrb- : given': 3,
#  'such as english': 3,
#  'in any case': 3,
#  'is often <UNK>': 3,
#  ', the first': 3,
#  'some of which': 3,
#  'many other languages': 3,
#  ', regardless of': 3,
#  ', determine the': 3,
#  'of speech .': 3,
#  'can be a': 3,
#  'be a noun': 3,
#  'others . </s>': 3,
#  '<UNK> <UNK> to': 3,
#  '<UNK> to a': 3,
#  '`` what is': 3,
#  'what is the': 3,
#  'given a chunk': 3,
#  'who is the': 3,
#  '-lrb- also known': 3,
#  'sentence boundaries .': 3,
#  'of a person': 3,
#  'the speech .': 3,
#  'this is the': 3,
#  'speech segmentation is': 3,
#  'segmentation is a': 3,
#  'languages , the': 3,
#  '<UNK> , so': 3,
#  '<s> speech segmentation': 3,
#  'into words .': 3,
#  'of which is': 3,
#  'text segmentation is': 3,
#  'more than one': 3,
#  '<s> for this': 3,
#  'of words and': 3,
#  '<s> in some': 3,
#  '-rrb- , but': 3,
#  'the extraction of': 3,
#  '<UNK> natural language': 3,
#  'statistical methods to': 3,
#  ', in order': 3,
#  'the definition of': 3,
#  'to a given': 3,
#  'then , the': 3,
#  'the <UNK> project': 3,
#  '<UNK> , in': 3,
#  'set of <UNK>': 3,
#  ', <UNK> j.': 3,
#  ', <UNK> d.': 3,
#  'automatic speech recognition': 3,
#  'evaluation . </s>': 3,
#  'user . </s>': 3,
#  'is based on': 3,
#  'the gold standard': 3,
#  '<UNK> , to': 3,
#  '-lrb- e.g. the': 3,
#  'system , the': 3,
#  ', but this': 3,
#  '<s> although the': 3,
#  'which are <UNK>': 3,
#  'quality of a': 3,
#  '<UNK> -rrb- <UNK>': 3,
#  'programs . </s>': 3,
#  'computer program .': 3,
#  'program . </s>': 3,
#  'original text .': 3,
#  '-rrb- , or': 3,
#  'target language is': 3,
#  'the possibility of': 3,
#  'are <UNK> <UNK>': 3,
#  'in an <UNK>': 3,
#  'machine translation .': 3,
#  'translation . </s>': 3,
#  'university of <UNK>': 3,
#  'and <UNK> -rrb-': 3,
#  'computer . </s>': 3,
#  '<s> <UNK> this': 3,
#  'the text ,': 3,
#  'of the grammar': 3,
#  'the source language': 3,
#  'text in the': 3,
#  'it has been': 3,
#  'at the <UNK>': 3,
#  'which means that': 3,
#  'the text in': 3,
#  'according to the': 3,
#  'speaker . </s>': 3,
#  'use . </s>': 3,
#  'approaches . </s>': 3,
#  'can be viewed': 3,
#  'an attempt to': 3,
#  'attempt to <UNK>': 3,
#  '<s> the problem': 3,
#  'between the two': 3,
#  'the late <UNK>': 3,
#  'part of a': 3,
#  ', and not': 3,
#  'kind of <UNK>': 3,
#  'to be done': 3,
#  'by a human': 3,
#  'or <UNK> .': 3,
#  ', but also': 3,
#  'use , and': 3,
#  'human <UNK> ,': 3,
#  'appear in the': 3,
#  '<UNK> in a': 3,
#  'and <UNK> of': 3,
#  'and <UNK> and': 3,
#  'year . </s>': 3,
#  ', but it': 3,
#  'which has been': 3,
#  'has been applied': 3,
#  'most of the': 3,
#  'influenced by the': 3,
#  'etc. -rrb- ,': 3,
#  'the phenomenon of': 3,
#  '<UNK> <UNK> as': 3,
#  'of the united': 3,
#  'used in many': 3,
#  '<UNK> , paul': 3,
#  ', paul <UNK>': 3,
#  '<UNK> , john': 3,
#  'michael <UNK> ,': 3,
#  'is <UNK> .': 3,
#  'a subset of': 3,
#  'the goal is': 3,
#  'goal is to': 3,
#  '<s> in general': 3,
#  'require the use': 3,
#  'summarization systems are': 3,
#  'possible . </s>': 3,
#  'will generate a': 3,
#  'such as a': 3,
#  ', and you': 3,
#  'to be able': 3,
#  "<UNK> '' .": 3,
#  '<s> also ,': 3,
#  'unigram , bigram': 3,
#  ', bigram ,': 3,
#  'are likely to': 3,
#  'in the following': 3,
#  'manner . </s>': 3,
#  'correct . </s>': 3,
#  'which is the': 3,
#  '-lrb- <UNK> =': 3,
#  '<s> design choices': 3,
#  'case . </s>': 3,
#  'corpus -rrb- ,': 3,
#  'the <UNK> -lrb-': 3,
#  'we need to': 3,
#  'a way to': 3,
#  'have been used': 3,
#  'could be used': 3,
#  'unsupervised keyphrase extraction': 3,
#  'the notion of': 3,
#  'networks . </s>': 3,
#  'i.e. , the': 3,
#  "`` natural ''": 3,
#  'can be filtered': 3,
#  'more or less': 3,
#  ', `` <UNK>': 3,
#  'is likely to': 3,
#  "`` classification ''": 3,
#  "classification '' .": 3,
#  'the importance of': 3,
#  'an <UNK> <UNK>': 3,
#  '<s> the most': 3,
#  'are <UNK> .': 3,
#  'determine if the': 3,
#  '<s> a <UNK>': 3,
#  'is that the': 3,
#  'the sentences in': 3,
#  'sufficient . </s>': 3,
#  'be used for': 3,
#  'the document .': 3,
#  'the same time': 3,
#  'same time ,': 3,
#  'score . </s>': 3,
#  'sentences that are': 3,
#  'very similar to': 3,
#  'similar to many': 3,
#  'from the <UNK>': 3,
#  ', and other': 3,
#  '<UNK> that <UNK>': 3,
#  'in addition to': 3,
#  'has also been': 3,
#  ', there are': 3,
#  'are systems that': 3,
#  ', and there': 3,
#  'analysis of <UNK>': 3,
#  'of <UNK> of': 3,
#  'high level of': 3,
#  '<UNK> more <UNK>': 3,
#  'more <UNK> ,': 3,
#  '-rrb- is the': 3,
#  'the system needs': 3,
#  'system needs to': 3,
#  '<s> as in': 3,
#  'as in other': 3,
#  'texts . </s>': 3,
#  'and <UNK> -lrb-': 3,
#  'pollen levels for': 3,
#  'levels for friday': 3,
#  'for friday have': 3,
#  'friday have increased': 3,
#  'have increased from': 3,
#  'increased from the': 3,
#  'from the moderate': 3,
#  'the moderate to': 3,
#  'moderate to high': 3,
#  'to high levels': 3,
#  'high levels of': 3,
#  'levels of yesterday': 3,
#  'with values of': 3,
#  'around 6 to': 3,
#  '6 to 7': 3,
#  'to 7 across': 3,
#  '7 across most': 3,
#  'across most parts': 3,
#  'most parts of': 3,
#  'parts of the': 3,
#  'of the country': 3,
#  'example , deciding': 3,
#  'systems have been': 3,
#  'in this area': 3,
#  'interest in using': 3,
#  'in using nlg': 3,
#  'using nlg to': 3,
#  'framework . </s>': 3,
#  'a person ,': 3,
#  'difficult to <UNK>': 3,
#  'the most popular': 3,
#  'comprehension . </s>': 3,
#  'problems . </s>': 3,
#  'a rich lexicon': 3,
#  'can be seen': 3,
#  'for natural language': 3,
#  '<s> a number': 3,
#  ', but they': 3,
#  'to the use': 3,
#  'it is <UNK>': 3,
#  'code . </s>': 3,
#  'in <UNK> <UNK>': 3,
#  'u.s. patent <UNK>': 3,
#  "reader 's digest": 3,
#  '<UNK> by <UNK>': 3,
#  'in the uk': 3,
#  '<s> two years': 3,
#  'two years later': 3,
#  'years later ,': 3,
#  'recognition accuracy .': 3,
#  'widely used in': 3,
#  ', <UNK> ocr': 3,
#  'available . </s>': 3,
#  '<UNK> words ,': 3,
#  'on-line character recognition': 3,
#  'recognition , and': 3,
#  'area of research': 3,
#  '<UNK> can be': 3,
#  'words in a': 3,
#  'computational linguistics ,': 3,
#  ', in <UNK>': 3,
#  '-rrb- , a': 3,
#  'ambiguous . </s>': 3,
#  'a verb ,': 3,
#  'verb , and': 3,
#  '-rrb- in the': 3,
#  'an adjective or': 3,
#  'adjective or a': 3,
#  ', <UNK> for': 3,
#  'in the brown': 3,
#  'brown corpus -rrb-': 3,
#  'can be expressed': 3,
#  'a table of': 3,
#  'the probabilities of': 3,
#  'of speech -rrb-': 3,
#  'speech -rrb- .': 3,
#  '<s> that is': 3,
#  'is , they': 3,
#  'the <UNK> algorithm': 3,
#  '<s> hidden markov': 3,
#  'as an adjective': 3,
#  'in the last': 3,
#  'the set of': 3,
#  '<UNK> -lrb- ``': 3,
#  'refers to the': 3,
#  'is difficult to': 3,
#  '<s> -lrb- see': 3,
#  'a context-free grammar': 3,
#  'right . </s>': 3,
#  'by <UNK> ,': 3,
#  'to find the': 3,
#  'ontologies . </s>': 3,
#  'the answer .': 3,
#  'the question is': 3,
#  'e.g. , ``': 3,
#  "? '' </s>": 3,
#  'to <UNK> with': 3,
#  'not present in': 3,
#  'of the question': 3,
#  'a qa system': 3,
#  'as a <UNK>': 3,
#  'questions about the': 3,
#  'a <UNK> system': 3,
#  '<UNK> questions ,': 3,
#  'is the problem': 3,
#  'performance . </s>': 3,
#  'of sentiment analysis': 3,
#  'rather than a': 3,
#  '<UNK> , where': 3,
#  'speech recognition in': 3,
#  'air traffic controllers': 3,
#  'asr in the': 3,
#  'video <UNK> ,': 3,
#  'speed . </s>': 3,
#  'accuracy of speech': 3,
#  'are used ,': 3,
#  'used , therefore': 3,
#  ', therefore it': 3,
#  'therefore it becomes': 3,
#  'layer of nodes': 3,
#  'speech and language': 3,
#  "recognition '' by": 3,
#  'project , which': 3,
#  'speech recognition performance': 3,
#  '<UNK> of speech': 3,
#  "` <UNK> '": 3,
#  'but not words': 3,
#  'not words are': 3,
#  'words are delimited': 3,
#  'field of computer': 2,
#  ', artificial intelligence': 2,
#  'concerned with the': 2,
#  'the <UNK> between': 2,
#  '<s> in theory': 2,
#  'in theory ,': 2,
#  'language processing is': 2,
#  'processing is a': 2,
#  'interaction . </s>': 2,
#  'language understanding is': 2,
#  'is sometimes referred': 2,
#  'to as an': 2,
#  'the ability to': 2,
#  '<s> on the': 2,
#  "'' , <UNK>": 2,
#  'analysis of natural': 2,
#  'are grounded in': 2,
#  'grounded in machine': 2,
#  'in machine learning': 2,
#  'an understanding of': 2,
#  'of a number': 2,
#  'number of <UNK>': 2,
#  ', including linguistics': 2,
#  'including linguistics ,': 2,
#  'and statistics .': 2,
#  '<s> for a': 2,
#  'the types of': 2,
#  'example of an': 2,
#  '<s> in 1950': 2,
#  'in 1950 ,': 2,
#  'program to <UNK>': 2,
#  'conversation with a': 2,
#  'on the basis': 2,
#  '<s> the georgetown': 2,
#  'involved fully automatic': 2,
#  'fully automatic translation': 2,
#  'automatic translation of': 2,
#  'sixty russian sentences': 2,
#  'russian sentences into': 2,
#  'sentences into english': 2,
#  'into english .': 2,
#  'the authors claimed': 2,
#  'authors claimed that': 2,
#  'claimed that within': 2,
#  'that within three': 2,
#  'five years ,': 2,
#  'years , machine': 2,
#  'machine translation would': 2,
#  'translation would be': 2,
#  'be a solved': 2,
#  'a solved problem': 2,
#  'solved problem .': 2,
#  'real progress was': 2,
#  'progress was much': 2,
#  'was much slower': 2,
#  'much slower ,': 2,
#  ', and after': 2,
#  'and after the': 2,
#  'after the alpac': 2,
#  'the alpac report': 2,
#  ', which found': 2,
#  'which found that': 2,
#  'research had failed': 2,
#  'had failed to': 2,
#  'failed to fulfill': 2,
#  'expectations , funding': 2,
#  'machine translation was': 2,
#  'reduced . </s>': 2,
#  'in machine translation': 2,
#  'the first statistical': 2,
#  'first statistical machine': 2,
#  'systems were developed': 2,
#  'were developed .': 2,
#  'developed . </s>': 2,
#  'systems developed in': 2,
#  'in the 1960s': 2,
#  "<UNK> '' <UNK>": 2,
#  'knowledge base ,': 2,
#  '<s> during the': 2,
#  '<UNK> began to': 2,
#  '<s> examples are': 2,
#  ', 1978 -rrb-': 2,
#  '1978 -rrb- ,': 2,
#  '<s> during this': 2,
#  'during this time': 2,
#  'this time ,': 2,
#  'hand-written rules .': 2,
#  'there was a': 2,
#  '<UNK> in nlp': 2,
#  'due both to': 2,
#  'both to the': 2,
#  "'s <UNK> and": 2,
#  'of <UNK> theories': 2,
#  '<UNK> theories of': 2,
#  'linguistics that <UNK>': 2,
#  'of the earliest-used': 2,
#  'algorithms , such': 2,
#  'trees , produced': 2,
#  ', produced systems': 2,
#  'produced systems of': 2,
#  'systems of hard': 2,
#  'of hard if-then': 2,
#  ...}

# %%
trigram.ngram_freq['<UNK NGRAM>']
# This is the number of trigram types whose frequency is 1. 
# Comparing this with the total number of trigrams below, we can see how large this is
# Out:
# 25904

# %%
sum(trigram.ngram_freq.values())
# Out:
# 34541
